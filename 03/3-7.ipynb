# %%
# Modelo Deep Learning que determina si una crítica cinematográfica es positiva o negativa
# Dataset: keras.IMDB

import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import models, layers
from keras.datasets import imdb

print("Cargando keras.IMDB")
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
print("Hecho")
# Out:
# Cargando keras.IMDB
# Hecho

# %%
# Vectorizar los datos
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
# Vectorizar las etiquetas
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
# Definición del modelo
# Sequential model, the simplest type of Keras model
model = models.Sequential()

# Input_shape=10000: Especifica que cada muestra tiene 10000 características (1D array)
model.add(layers.Input(shape=(10000,)))

# Core of the model: 3 Dense layers

# units=16: This specifies there are 16 neurons in this layer
# Activation function for the neuron: 'relu'
model.add(layers.Dense(16, activation='relu'))

# units=16: This specifies there are 16 neurons in this layer
# Activation function for the neuron: 'relu'
model.add(layers.Dense(16, activation='relu'))

# units=1: This specifies there is 1 neuros in this layer
# Activation function for the neuron: 'sigmoid'
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# 2025-12-30 19:27:23.837612: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-12-30 19:27:23.837678: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-12-30 19:27:23.837687: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-12-30 19:27:23.837851: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-12-30 19:27:23.837860: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# print("Entrenamiento del modelo")
# model.fit(x_train, y_train, epochs=20, batch_size=512)
# Out:
# Entrenamiento del modelo
# Epoch 1/20
# 2025-12-30 19:27:26.075323: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7942 - loss: 0.4878
# Epoch 2/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8996 - loss: 0.2850
# Epoch 3/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9217 - loss: 0.2216
# Epoch 4/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9340 - loss: 0.1871
# Epoch 5/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9434 - loss: 0.1622
# Epoch 6/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9487 - loss: 0.1478
# Epoch 7/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9531 - loss: 0.1340
# Epoch 8/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9585 - loss: 0.1217
# Epoch 9/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9619 - loss: 0.1132
# Epoch 10/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9684 - loss: 0.1008
# Epoch 11/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9703 - loss: 0.0940
# Epoch 12/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9734 - loss: 0.0863
# Epoch 13/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9753 - loss: 0.0812
# Epoch 14/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9783 - loss: 0.0756
# Epoch 15/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9794 - loss: 0.0716
# Epoch 16/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9819 - loss: 0.0656
# Epoch 17/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9838 - loss: 0.0603
# Epoch 18/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9860 - loss: 0.0559
# Epoch 19/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9866 - loss: 0.0547
# Epoch 20/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9882 - loss: 0.0508

# %%
# Divido las muestras y etiquetas de training en dos grupos
# 1 - 10.000     : x_val, y_val: 
# 10.000 - 25.000: partial_x_train, partial_y_train

# Muestras 0 - 10,000 de training
x_val = x_train[:10000]

# Muestras 10,000 - 25.000 de training
partial_x_train = x_train[10000:]

# Etiquetas 0 - 10.000 de training
y_val = y_train[:10000]

# Etiquetas 10.000 - 25.000 de training
partial_y_train = y_train[10000:]

# %%
print("Entrenamiento del modelo")
# history = model.fit(x_train, y_train, epochs=20, batch_size=512)
history = model.fit(partial_x_train, partial_y_train, epochs=20, batch_size=512, validation_data=(x_val, y_val))
# Out:
# Entrenamiento del modelo
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9902 - loss: 0.0439 - val_accuracy: 0.9790 - val_loss: 0.0657
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9937 - loss: 0.0351 - val_accuracy: 0.9884 - val_loss: 0.0512
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9935 - loss: 0.0331 - val_accuracy: 0.9840 - val_loss: 0.0606
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9969 - loss: 0.0235 - val_accuracy: 0.9757 - val_loss: 0.0792
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9947 - loss: 0.0286 - val_accuracy: 0.9795 - val_loss: 0.0735
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9948 - loss: 0.0240 - val_accuracy: 0.9758 - val_loss: 0.0825
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9979 - loss: 0.0165 - val_accuracy: 0.9735 - val_loss: 0.0885
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9961 - loss: 0.0199 - val_accuracy: 0.9701 - val_loss: 0.0980
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9953 - loss: 0.0213 - val_accuracy: 0.9671 - val_loss: 0.1071
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9983 - loss: 0.0120 - val_accuracy: 0.9632 - val_loss: 0.1166
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9969 - loss: 0.0162 - val_accuracy: 0.9627 - val_loss: 0.1233
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9973 - loss: 0.0134 - val_accuracy: 0.9590 - val_loss: 0.1340
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9985 - loss: 0.0092 - val_accuracy: 0.9582 - val_loss: 0.1414
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9973 - loss: 0.0127 - val_accuracy: 0.9563 - val_loss: 0.1490
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9973 - loss: 0.0120 - val_accuracy: 0.9524 - val_loss: 0.1581
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9989 - loss: 0.0070 - val_accuracy: 0.9493 - val_loss: 0.1714
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9973 - loss: 0.0112 - val_accuracy: 0.9494 - val_loss: 0.1739
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9990 - loss: 0.0059 - val_accuracy: 0.9493 - val_loss: 0.1786
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9968 - loss: 0.0106 - val_accuracy: 0.9471 - val_loss: 0.1870
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9992 - loss: 0.0051 - val_accuracy: 0.9467 - val_loss: 0.1910
