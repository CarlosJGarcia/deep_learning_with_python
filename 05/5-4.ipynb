# %%
import os, shutil

original_dataset_dir = '/Users/garcic28/Documents/python/deep_learning_with_python/05/kaggle_original_data/kagglecatsanddogs_5340/PetImages'

# Crea el directorio cats_and_dogs_small
base_dir = '/Users/garcic28/Documents/python/deep_learning_with_python/05/cats_and_dogs_small'
os.makedirs(base_dir, exist_ok=True) # exist_ok=True prevents the error if the directory is already there

# Crea los subdirectorios train, validation y test
train_dir = os.path.join(base_dir, 'train')
os.makedirs(train_dir, exist_ok=True)  
validation_dir = os.path.join(base_dir, 'validation')
os.makedirs(validation_dir, exist_ok=True)
test_dir = os.path.join(base_dir, 'test')
os.makedirs(test_dir, exist_ok=True)

# Dentro de cada uno de los tres, crea los subdirectorios cats y dogs
train_cats_dir = os.path.join(train_dir, 'cats')
os.makedirs(train_cats_dir, exist_ok=True)
train_dogs_dir = os.path.join(train_dir, 'dogs')
os.makedirs(train_dogs_dir, exist_ok=True)

validation_cats_dir = os.path.join(validation_dir, 'cats')
os.makedirs(validation_cats_dir, exist_ok=True)
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
os.makedirs(validation_dogs_dir, exist_ok=True)

test_cats_dir = os.path.join(test_dir, 'cats')
os.makedirs(test_cats_dir, exist_ok=True)
test_dogs_dir = os.path.join(test_dir, 'dogs')
os.makedirs(test_dogs_dir, exist_ok=True)


# Copia 0-999 Training cats (1000)
fnames = ['{}.jpg'.format(i) for i in range(1000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir+'/Cat', fname)
    dst = os.path.join(train_cats_dir, 'cat.'+fname)
    shutil.copyfile(src, dst)

# Copia 1000-1499 Validation cats (500)
fnames = ['{}.jpg'.format(i) for i in range(1000, 1500)]
for fname in fnames:
    src = os.path.join(original_dataset_dir+'/Cat', fname)
    dst = os.path.join(validation_cats_dir, 'cat.'+fname)
    shutil.copyfile(src, dst)

# Copia 1500-1999 Test cats (500)
fnames = ['{}.jpg'.format(i) for i in range(1500, 2000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir+'/Cat', fname)
    dst = os.path.join(test_cats_dir, 'cat.'+fname)
    shutil.copyfile(src, dst)

# Copia 0-999 Training dogs (1000)
fnames = ['{}.jpg'.format(i) for i in range(1000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir+'/Dog', fname)
    dst = os.path.join(train_dogs_dir, 'dog.'+fname)
    shutil.copyfile(src, dst)

# Copia 1000-1499 Validation dogs (500)
fnames = ['{}.jpg'.format(i) for i in range(1000, 1500)]
for fname in fnames:
    src = os.path.join(original_dataset_dir+'/Dog', fname)
    dst = os.path.join(validation_dogs_dir, 'dog.'+fname)
    shutil.copyfile(src, dst)

# Copia 1500-1999 Test dogs (500)
fnames = ['{}.jpg'.format(i) for i in range(1500, 2000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir+'/Dog', fname)
    dst = os.path.join(test_dogs_dir, 'dog.'+fname)
    shutil.copyfile(src, dst)
# Out:
# src:  /Users/garcic28/Documents/python/deep_learning_with_python/05/kaggle_original_data/kagglecatsanddogs_5340/PetImages/Dog/1999.jpg
# dst:  /Users/garcic28/Documents/python/deep_learning_with_python/05/cats_and_dogs_small/test/dogs/dog.1999.jpg
